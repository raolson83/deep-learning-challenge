# %% [markdown]
# <a href="https://colab.research.google.com/github/raolson83/deep-learning-challenge/blob/main/Copy_of_Starter_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df2 = application_df.drop(['EIN','NAME'], axis =1)
application_df2.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df2.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df2['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T10','T9','T13','T12','T2','T25','T14','T29','T15','T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classifications= application_df2['CLASSIFICATION'].value_counts()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df2['CLASSIFICATION'].value_counts().loc[lambda x : x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = classifications.drop(['C1000','C2000','C1200','C3000','C2100'])
classifications_to_replace = classifications_to_replace.index


# # Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# # Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df2 = pd.get_dummies(application_df2, columns=['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS'])
application_df2.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  \
# 0       1     5000              1                     1                     0
# 1       1   108590              1                     0                     0
# 2       1     5000              0                     0                     0
# 3       1     6692              1                     0                     0
# 4       1   142590              1                     0                     0
#
#    APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  APPLICATION_TYPE_T15  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  INCOME_AMT_1-9999  \
# 0                     0                     0  ...                  0
# 1                     0                     0  ...                  1
# 2                     0                     0  ...                  0
# 3                     0                     0  ...                  0
# 4                     0                     0  ...                  0
#
#    INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  \
# 0                       0                         0                   0
# 1                       0                         0                   0
# 2                       0                         0                   0
# 3                       1                         0                   0
# 4                       0                         1                   0
#
#    INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  INCOME_AMT_50M+  \
# 0                 0                       0                0
# 1                 0                       0                0
# 2                 0                       0                0
# 3                 0                       0                0
# 4                 0                       0                0
#
#    INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                  0                         1                         0
# 1                  0                         1                         0
# 2                  0                         1                         0
# 3                  0                         1                         0
# 4                  0                         1                         0
#
# [5 rows x 117 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_df2.drop(['IS_SUCCESSFUL','STATUS'],axis = 1)
y = application_df2['IS_SUCCESSFUL']
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
pip install keras_tuner
# Out:
# Collecting keras_tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (2.31.0)
# Collecting kt-legacy (from keras_tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (2024.2.2)
# Installing collected packages: kt-legacy, keras_tuner
# Successfully installed keras_tuner-1.4.7 kt-legacy-1.0.5

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=30,
        step=5), activation=activation, input_dim=len(X_train_scaled[0])))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 5)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=30,
            step=5),
            activation=activation))

    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

    return nn_model


# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2)


# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))

# Get top 3 model hyperparameters and print the values
top_hyper = tuner.get_best_hyperparameters(3)
for param in top_hyper:
    print(param.values)
# Evaluate the top 3 models against the test dataset
top_model = tuner.get_best_models(3)
for model in top_model:
    model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test,verbose=2)
    print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Trial 56 Complete [00h 01m 24s]
# val_accuracy: 0.7318950295448303
#
# Best val_accuracy So Far: 0.7334110736846924
# Total elapsed time: 00h 25m 27s
# {'activation': 'tanh', 'first_units': 21, 'num_layers': 4, 'units_0': 16, 'units_1': 1, 'units_2': 6, 'units_3': 21, 'units_4': 1, 'tuner/epochs': 7, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
# {'activation': 'tanh', 'first_units': 1, 'num_layers': 2, 'units_0': 11, 'units_1': 1, 'units_2': 1, 'units_3': 21, 'units_4': 6, 'tuner/epochs': 3, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
# {'activation': 'tanh', 'first_units': 1, 'num_layers': 1, 'units_0': 11, 'units_1': 21, 'units_2': 26, 'units_3': 1, 'units_4': 1, 'tuner/epochs': 7, 'tuner/initial_epoch': 3, 'tuner/bracket': 2, 'tuner/round': 1, 'tuner/trial_id': '0005'}
# 268/268 - 1s - loss: 0.5560 - accuracy: 0.7334 - 865ms/epoch - 3ms/step
# Loss: 0.5559610724449158, Accuracy: 0.7334110736846924
# 268/268 - 1s - loss: 0.5772 - accuracy: 0.7331 - 762ms/epoch - 3ms/step
# Loss: 0.577177882194519, Accuracy: 0.7330612540245056
# 268/268 - 1s - loss: 0.5743 - accuracy: 0.7325 - 534ms/epoch - 2ms/step
# Loss: 0.5742883086204529, Accuracy: 0.732478141784668

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
# Create the Keras Sequential model
nn = tf.keras.models.Sequential()


# First hidden layer
nn.add(tf.keras.layers.Dense(units=100, activation= "relu", input_dim=len(X_train_scaled[0])))


# Second hidden layer
nn.add(tf.keras.layers.Dense(units=50, activation= "relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation= "sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               11600
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 16701 (65.24 KB)
# Trainable params: 16701 (65.24 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint
# Define the ModelCheckpoint callback
mc = ModelCheckpoint('weights{epoch:08d}.h5', save_weights_only=True, save_freq=5)

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[mc])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5728 - accuracy: 0.7208
# Epoch 2/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5538 - accuracy: 0.7293
# Epoch 3/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5495 - accuracy: 0.7304
# Epoch 4/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5475 - accuracy: 0.7329
# Epoch 5/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5458 - accuracy: 0.7341
# Epoch 6/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5446 - accuracy: 0.7350
# Epoch 7/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5439 - accuracy: 0.7341
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5428 - accuracy: 0.7353
# Epoch 9/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5421 - accuracy: 0.7363
# Epoch 10/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5411 - accuracy: 0.7360
# Epoch 11/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5412 - accuracy: 0.7355
# Epoch 12/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5403 - accuracy: 0.7367
# Epoch 13/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5393 - accuracy: 0.7373
# Epoch 14/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5393 - accuracy: 0.7371
# Epoch 15/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5387 - accuracy: 0.7376
# Epoch 16/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5383 - accuracy: 0.7381
# Epoch 17/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5384 - accuracy: 0.7376
# Epoch 18/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5375 - accuracy: 0.7392
# Epoch 19/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5371 - accuracy: 0.7386
# Epoch 20/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5371 - accuracy: 0.7382
# Epoch 21/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5365 - accuracy: 0.7383
# Epoch 22/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5364 - accuracy: 0.7395
# Epoch 23/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5363 - accuracy: 0.7388
# Epoch 24/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5355 - accuracy: 0.7395
# Epoch 25/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5353 - accuracy: 0.7396
# Epoch 26/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5346 - accuracy: 0.7399
# Epoch 27/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5347 - accuracy: 0.7401
# Epoch 28/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5344 - accuracy: 0.7402
# Epoch 29/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5348 - accuracy: 0.7397
# Epoch 30/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5340 - accuracy: 0.7410
# Epoch 31/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5344 - accuracy: 0.7399
# Epoch 32/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5336 - accuracy: 0.7406
# Epoch 33/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5333 - accuracy: 0.7408
# Epoch 34/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5333 - accuracy: 0.7405
# Epoch 35/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5332 - accuracy: 0.7416
# Epoch 36/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5327 - accuracy: 0.7411
# Epoch 37/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5330 - accuracy: 0.7411
# Epoch 38/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5327 - accuracy: 0.7409
# Epoch 39/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5323 - accuracy: 0.7412
# Epoch 40/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5322 - accuracy: 0.7415
# Epoch 41/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5322 - accuracy: 0.7414
# Epoch 42/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5316 - accuracy: 0.7412
# Epoch 43/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5321 - accuracy: 0.7413
# Epoch 44/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5315 - accuracy: 0.7419
# Epoch 45/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5311 - accuracy: 0.7418
# Epoch 46/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5312 - accuracy: 0.7415
# Epoch 47/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5311 - accuracy: 0.7420
# Epoch 48/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5314 - accuracy: 0.7415
# Epoch 49/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5310 - accuracy: 0.7418
# Epoch 50/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5307 - accuracy: 0.7423
# Epoch 51/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5307 - accuracy: 0.7418
# Epoch 52/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5305 - accuracy: 0.7416
# Epoch 53/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5300 - accuracy: 0.7424
# Epoch 54/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5316 - accuracy: 0.7421
# Epoch 55/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5298 - accuracy: 0.7416
# Epoch 56/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5293 - accuracy: 0.7427
# Epoch 57/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5303 - accuracy: 0.7416
# Epoch 58/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5297 - accuracy: 0.7425
# Epoch 59/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5299 - accuracy: 0.7423
# Epoch 60/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5295 - accuracy: 0.7423
# Epoch 61/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5297 - accuracy: 0.7426
# Epoch 62/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5296 - accuracy: 0.7421
# Epoch 63/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5293 - accuracy: 0.7425
# Epoch 64/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5293 - accuracy: 0.7423
# Epoch 65/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5294 - accuracy: 0.7427
# Epoch 66/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5291 - accuracy: 0.7426
# Epoch 67/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5294 - accuracy: 0.7425
# Epoch 68/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5289 - accuracy: 0.7425
# Epoch 69/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5285 - accuracy: 0.7423
# Epoch 70/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5288 - accuracy: 0.7430
# Epoch 71/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5283 - accuracy: 0.7422
# Epoch 72/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5287 - accuracy: 0.7425
# Epoch 73/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5295 - accuracy: 0.7431
# Epoch 74/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5282 - accuracy: 0.7425
# Epoch 75/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5281 - accuracy: 0.7432
# Epoch 76/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5284 - accuracy: 0.7423
# Epoch 77/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5282 - accuracy: 0.7430
# Epoch 78/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5282 - accuracy: 0.7426
# Epoch 79/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5287 - accuracy: 0.7423
# Epoch 80/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5287 - accuracy: 0.7432
# Epoch 81/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5280 - accuracy: 0.7428
# Epoch 82/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5280 - accuracy: 0.7429
# Epoch 83/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5278 - accuracy: 0.7428
# Epoch 84/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5276 - accuracy: 0.7430
# Epoch 85/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5286 - accuracy: 0.7421
# Epoch 86/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5275 - accuracy: 0.7432
# Epoch 87/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5278 - accuracy: 0.7430
# Epoch 88/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5274 - accuracy: 0.7432
# Epoch 89/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5279 - accuracy: 0.7417
# Epoch 90/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5274 - accuracy: 0.7431
# Epoch 91/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5270 - accuracy: 0.7433
# Epoch 92/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5276 - accuracy: 0.7434
# Epoch 93/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5276 - accuracy: 0.7424
# Epoch 94/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5274 - accuracy: 0.7432
# Epoch 95/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5273 - accuracy: 0.7434
# Epoch 96/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5271 - accuracy: 0.7427
# Epoch 97/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5270 - accuracy: 0.7427
# Epoch 98/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5273 - accuracy: 0.7431
# Epoch 99/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5280 - accuracy: 0.7427
# Epoch 100/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5270 - accuracy: 0.7433

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5662 - accuracy: 0.7293 - 460ms/epoch - 2ms/step
# Loss: 0.5661854147911072, Accuracy: 0.7293294668197632

# %%
import matplotlib.pyplot as plt

# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)


# Increase the index by 1 to match the number of epochs
history_df.index += 1


# Plot the loss
history_df.plot(y = "loss")
plt.show()
# Plot the accuracy
history_df.plot(y='accuracy')
plt.show()

# %%
# Export our model to HDF5 file
from google.colab import files

nn.save('AlphabetSoupCharity.h5')
files.download('AlphabetSoupCharity.h5')
